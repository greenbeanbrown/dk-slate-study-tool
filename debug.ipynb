# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np
import math

import plotly.express as px

pd.options.display.max_rows = 999999
pd.options.display.max_columns = 99999

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:85% !important; }</style>"))

#import sys
#sys.path.insert(0, 'C:/Users/Sean/Documents/python/ufc/scripts/functions/')

from functions import clean_entry_name, melt_crosstab, cleanup_mlb_lineup_data, create_points_own_df, prep_raw_dk_contest_data
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# <style>.container { width:85% !important; }</style>

# %%
# Setup paths
data_dir = 'C:/Users/ahote/Documents/dk_slate_study_tool/data/'
file_name = '25dollar_single_entry_500entries.csv'

file_path = data_dir + file_name

# %%
# Read in data
df = pd.read_csv(file_path)
print(len(df))
# Out:
# 564

# %%
df.tail()
# Out:
#      Rank     EntryId      EntryName  TimeRemaining  Points  \
# 559   560  2766587608   bigephenom10              0    50.7
# 560   561  2766447009     polrif2015              0     0.0
# 561   561  2766550496  HOFbarrybonds              0     0.0
# 562   561  2766565796      ndpearman              0     0.0
# 563   561  2766592235       hastypop              0     0.0
#
#                                                 Lineup  Unnamed: 6 Player  \
# 559  P Lance McCullers Jr. P Dylan Cease OF Yordan ...         NaN    NaN
# 560                                                NaN         NaN    NaN
# 561                                                NaN         NaN    NaN
# 562                                                NaN         NaN    NaN
# 563                                                NaN         NaN    NaN
#
#     Roster Position %Drafted  FPTS
# 559             NaN      NaN   NaN
# 560             NaN      NaN   NaN
# 561             NaN      NaN   NaN
# ...

# %%
df = df.dropna()

print(len(df))

df.tail()
# Out:
# 560
# 555    P Lance McCullers Jr. P Robbie Ray OF Bryce Ha...
# 556    P Robbie Ray P Kyle Hendricks 1B Rhys Hoskins ...
# 557    P Lance McCullers Jr. P Dylan Cease 2B Marcus ...
# 558    P Julio Urías P Dylan Cease OF Yordan Alvarez ...
# 559    P Lance McCullers Jr. P Dylan Cease OF Yordan ...
# Name: Lineup, dtype: object

# %%
exposures_df = cleanup_mlb_lineup_data(df)

exposures_df
# Out:
#      Rank     EntryId            EntryName      Points                   P1  \
# 0       1  2766590066                bfd77  147.100000      Adam Wainwright
# 1       2  2766137098     TheHumanCespedes  144.900000          Julio Urías
# 2       3  2766338839          KellyKrobar  134.750000  Lance McCullers Jr.
# 3       4  2766619694             ahertz33  132.800000          Julio Urías
# 4       5  2766466496             status78  131.700000  Lance McCullers Jr.
# 5       6  2766527048              tfbrown  129.750000  Lance McCullers Jr.
# 6       7  2766501473           playahata1  128.200000          Julio Urías
# 7       8  2766472049           CatCoulter  127.200000           Logan Webb
# 8       9  2766555377            beckertad  126.850000          Julio Urías
# 9      10  2766596869     Shpielers_United  126.200000  Lance McCullers Jr.
# 10     11  2766518079         DynastyPlaya  125.500000  Lance McCullers Jr.
# ...

# %%
df.head()
# Out:
#    Rank     EntryId         EntryName  TimeRemaining  Points  \
# 0     1  2766590066             bfd77              0  147.10
# 1     2  2766137098  TheHumanCespedes              0  144.90
# 2     3  2766338839       KellyKrobar              0  134.75
# 3     4  2766619694          ahertz33              0  132.80
# 4     5  2766466496          status78              0  131.70
#
#                                               Lineup  Unnamed: 6  \
# 0  P Adam Wainwright P Jordan Lyles 1B Vladimir G...         NaN
# 1  P Julio Urías P Jordan Lyles 1B Vladimir Guerr...         NaN
# 2  P Lance McCullers Jr. P Matt Manning OF Nelson...         NaN
# 3  P Julio Urías P Kyle Hendricks 1B Vladimir Gue...         NaN
# 4  P Lance McCullers Jr. P Dylan Cease 1B Vladimi...         NaN
#
#                 Player Roster Position %Drafted   FPTS
# 0  Lance McCullers Jr.               P   68.26%  13.85
# 1          Dylan Cease               P   33.51%   9.85
# ...

# %%
test = prep_raw_dk_contest_data(df, 'MLB')

# %%
test[0].head()
# Out:
#                 player position  ownership  points
# 0  Lance McCullers Jr.        P      68.26   13.85
# 1          Dylan Cease        P      33.51    9.85
# 2      Adam Wainwright        P      30.32   19.55
# 3         Bryce Harper       OF      28.90   11.00
# 4        Josh Harrison       3B      28.37    7.00

# %%
test[1].head()
# Out:
#    Rank     EntryId         EntryName  Points                   P1  \
# 0     1  2766590066             bfd77  147.10      Adam Wainwright
# 1     2  2766137098  TheHumanCespedes  144.90          Julio Urías
# 2     3  2766338839       KellyKrobar  134.75  Lance McCullers Jr.
# 3     4  2766619694          ahertz33  132.80          Julio Urías
# 4     5  2766466496          status78  131.70  Lance McCullers Jr.
#
#                P2                      C               1B                 2B  \
# 0    Jordan Lyles  Vladimir Guerrero Jr.     Tim Anderson      Nolan Arenado
# 1    Jordan Lyles  Vladimir Guerrero Jr.  Xander Bogaerts    George Springer
# 2    Matt Manning            Nelson Cruz     Tim Anderson      J.T. Realmuto
# 3  Kyle Hendricks  Vladimir Guerrero Jr.      Bo Bichette  Teoscar Hernández
# 4     Dylan Cease  Vladimir Guerrero Jr.    Carlos Correa      J.D. Martinez
#
#                   3B              SS             OF1             OF2  \
# ...
