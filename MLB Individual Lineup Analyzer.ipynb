# %%
# %load_ext autoreload
# %autoreload 2

import base64
import datetime
import io

import os
import glob

import dash
from dash.dependencies import Input, Output, State
import dash_core_components as dcc
import dash_html_components as html
import dash_table

import dash_bootstrap_components as dbc

import base64

import pandas as pd

import sys
sys.path.insert(0, '..')
from functions import cleanup_mlb_lineup_data, cleanup_mma_lineup_data, prep_raw_dk_contest_data, filter_dk_users, merge_team_logos, get_team_colors

# %%
# Input - an individual EntryName from DK contest csv and a df of aggregate lineups

# Output - a table showing that lineup

# %%
# First, call cleanup_mlb_linup_data() to get the dataframe we want from itts output

# %%
data_dir = 'C:/Users/Sean/Documents/python/dk_slate_study_tool/data/'
file_name = '10k_upper_deck_3_entry.csv'

file_path = data_dir + file_name

df = pd.read_csv(file_path)

# %%
test = cleanup_mlb_lineup_data(df)
# Out:
# > c:\users\sean\documents\python\dk_slate_study_tool\functions.py(132)cleanup_mlb_lineup_data()
#     131     import ipdb; ipdb.set_trace()
# --> 132     return(clean_lineup_data)
#     133
#
# ipdb> clean_lineup_data.head()
#    Rank     EntryId          EntryName  Points    raw_lineup_name  \
# 0     1  2770774912           youdacao  145.60     youdacao (3/3)
# 1     2  2770729630  cardinals_fan2415  139.65  cardinals_fan2415
# 2     3  2770577873       dwilliamsmma  139.60       dwilliamsmma
# 3     4  2771099755        tmasters777  137.60        tmasters777
# 4     5  2770697969            dacoltz  137.45      dacoltz (1/3)
#
#               P1              P2               C                     1B  \
# 0  Shohei Ohtani  Germán Márquez       Juan Soto            Jose Altuve
# 1  Shohei Ohtani  Michael Pineda       Juan Soto  Vladimir Guerrero Jr.
# 2  Shohei Ohtani  Germán Márquez    Jesse Winker          Carlos Correa
# ...

# %%
test.head()
# Out:
#    Rank     EntryId          EntryName  Points    raw_lineup_name  \
# 0     1  2770774912           youdacao  145.60     youdacao (3/3)
# 1     2  2770729630  cardinals_fan2415  139.65  cardinals_fan2415
# 2     3  2770577873       dwilliamsmma  139.60       dwilliamsmma
# 3     4  2771099755        tmasters777  137.60        tmasters777
# 4     5  2770697969            dacoltz  137.45      dacoltz (1/3)
#
#               P1              P2               C                     1B  \
# 0  Shohei Ohtani  Germán Márquez       Juan Soto            Jose Altuve
# 1  Shohei Ohtani  Michael Pineda       Juan Soto  Vladimir Guerrero Jr.
# 2  Shohei Ohtani  Germán Márquez    Jesse Winker          Carlos Correa
# 3  Shohei Ohtani  Germán Márquez     Bo Bichette         Salvador Perez
# 4    Luis Garcia   Shohei Ohtani  Yordan Alvarez          Carlos Correa
#
#               2B              3B             SS              OF1  \
# 0  Carlos Correa       Josh Bell  Josh Harrison      Kyle Tucker
# ...

# %%
def parse_mlb_lineup(lineups_df, entry_name):
    
    # Get the lineup for that exact entry_name
    entry_lineup = lineups_df[lineups_df['raw_lineup_name'] == entry_name]
    
    # Clean up some columns
    entry_lineup['DK User'] = entry_lineup['EntryName']
    #entry_lineup['Lineup Name'] == entry_lineup['raw_lineup_name']
    
    # Final columns and order
    output_cols = ['Rank', 'Points', 'DK User', 'P1','P2','C','1B','2B','3B','SS','OF1','OF2','OF3']
    
    entry_lineup = entry_lineup.transpose()

    return(entry_lineup)

# %%
parse_mlb_lineup(test, 'youdacao (3/3)')
# Out:
# C:\Users\Sean\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
#                                 0
# Rank                            1
# EntryId                2770774912
# EntryName                youdacao
# Points                      145.6
# raw_lineup_name    youdacao (3/3)
# P1                  Shohei Ohtani
# P2                 Germán Márquez
# C                       Juan Soto
# 1B                    Jose Altuve
# 2B                  Carlos Correa
# 3B                      Josh Bell
# SS                  Josh Harrison
# OF1                   Kyle Tucker
# OF2              Michael Brantley
# OF3              Martín Maldonado
# ...
