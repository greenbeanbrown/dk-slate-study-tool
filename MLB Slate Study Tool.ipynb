# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np
import math

import plotly.express as px

pd.options.display.max_rows = 999999
pd.options.display.max_columns = 99999

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:85% !important; }</style>"))

#import sys
#sys.path.insert(0, 'C:/Users/Sean/Documents/python/ufc/scripts/functions/')

from functions import clean_entry_name, melt_crosstab, cleanup_mlb_lineup_data, create_points_own_df
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# <style>.container { width:85% !important; }</style>

# %% [markdown]
# # INPUTS

# %%
# Setup paths
data_dir = 'C:/Users/ahote/Documents/dk_slate_study_tool/data/'
file_name = '25dollar_single_entry_500entries.csv'

file_path = data_dir + file_name

# %%
dk_users = ['Awesemo', 'giantsquid', 'bkreider', 'dacoltz', 'getloose', 'totoroll33', 'BigT44', 'I_Slewfoot_U', 'B_Heals152', 'thepickler']

# %% [markdown]
# # READ DATA

# %%
# Read in data
df = pd.read_csv(file_path)
print(len(df))
# Out:
# 564

# %%
df.head()
# Out:
#    Rank     EntryId         EntryName  TimeRemaining  Points  \
# 0     1  2766590066             bfd77              0  147.10
# 1     2  2766137098  TheHumanCespedes              0  144.90
# 2     3  2766338839       KellyKrobar              0  134.75
# 3     4  2766619694          ahertz33              0  132.80
# 4     5  2766466496          status78              0  131.70
#
#                                               Lineup  Unnamed: 6  \
# 0  P Adam Wainwright P Jordan Lyles 1B Vladimir G...         NaN
# 1  P Julio Urías P Jordan Lyles 1B Vladimir Guerr...         NaN
# 2  P Lance McCullers Jr. P Matt Manning OF Nelson...         NaN
# 3  P Julio Urías P Kyle Hendricks 1B Vladimir Gue...         NaN
# 4  P Lance McCullers Jr. P Dylan Cease 1B Vladimi...         NaN
#
#                 Player Roster Position %Drafted   FPTS
# 0  Lance McCullers Jr.               P   68.26%  13.85
# 1          Dylan Cease               P   33.51%   9.85
# 2      Adam Wainwright               P   30.32%  19.55
# 3         Bryce Harper              OF   28.90%  11.00
# 4        Josh Harrison              3B   28.37%   7.00

# %% [markdown]
# # PREP DATA
#
# ## We split the master data into 2 different datasets that in tandem will make the final output (have to do this because its basically 2 dataframes in a single csv side-by-side
#
# ## Dataset #1 - Player Points Scored and Contest Ownership
# ## Dataset #2 - Every Contest Entry Name and Lineup

# %%
# Create the 1st dataset
points_own_df = pd.DataFrame()

# Add the main datapoints
points_own_df['player'] = df.Player.dropna()
points_own_df['position'] = df['Roster Position'].dropna() 
# Need to clean this up a bit, the percentages are coming in as strings from the file so we convert to a float
# Strip the percentage sign from the last char and then cast
points_own_df['ownership'] = [float(ownership[:-1]) for ownership in  df['%Drafted'].dropna()]
points_own_df['points'] = df['FPTS'].dropna()

# Now clean the player name a bit - THIS SHOULDN'T BE NECESSARY NOW
#points_own_df['player'] = points_own_df['player'].apply(lambda row: clean_player_name(row)) 

print(len(points_own_df))
points_own_df.head()
# Out:
# 154
#                 player position  ownership  points
# 0  Lance McCullers Jr.        P      68.26   13.85
# 1          Dylan Cease        P      33.51    9.85
# 2      Adam Wainwright        P      30.32   19.55
# 3         Bryce Harper       OF      28.90   11.00
# 4        Josh Harrison       3B      28.37    7.00

# %%
# First thing to do is drop the nans from the Lineup field - these are empty lineups that people submitted and should not be included in this analysis
raw_lineup_data = df[['Rank','EntryId','EntryName','Points','Lineup']]
raw_lineup_data = raw_lineup_data.dropna()

# %%
raw_lineup_data.head()
# Out:
#    Rank     EntryId         EntryName  Points  \
# 0     1  2766590066             bfd77  147.10
# 1     2  2766137098  TheHumanCespedes  144.90
# 2     3  2766338839       KellyKrobar  134.75
# 3     4  2766619694          ahertz33  132.80
# 4     5  2766466496          status78  131.70
#
#                                               Lineup
# 0  P Adam Wainwright P Jordan Lyles 1B Vladimir G...
# 1  P Julio Urías P Jordan Lyles 1B Vladimir Guerr...
# 2  P Lance McCullers Jr. P Matt Manning OF Nelson...
# 3  P Julio Urías P Kyle Hendricks 1B Vladimir Gue...
# 4  P Lance McCullers Jr. P Dylan Cease 1B Vladimi...

# %%
# Clean up the raw dataframe, parse out the lineups, clean the username, etc..
agg_lineups = cleanup_mlb_lineup_data(raw_lineup_data)

agg_lineups.head()
# Out:
#    Rank     EntryId         EntryName  Points                   P1  \
# 0     1  2766590066             bfd77  147.10      Adam Wainwright
# 1     2  2766137098  TheHumanCespedes  144.90          Julio Urías
# 2     3  2766338839       KellyKrobar  134.75  Lance McCullers Jr.
# 3     4  2766619694          ahertz33  132.80          Julio Urías
# 4     5  2766466496          status78  131.70  Lance McCullers Jr.
#
#                P2                      C               1B                 2B  \
# 0    Jordan Lyles  Vladimir Guerrero Jr.     Tim Anderson      Nolan Arenado
# 1    Jordan Lyles  Vladimir Guerrero Jr.  Xander Bogaerts    George Springer
# 2    Matt Manning            Nelson Cruz     Tim Anderson      J.T. Realmuto
# 3  Kyle Hendricks  Vladimir Guerrero Jr.      Bo Bichette  Teoscar Hernández
# 4     Dylan Cease  Vladimir Guerrero Jr.    Carlos Correa      J.D. Martinez
#
#                   3B              SS             OF1             OF2  \
# 0  Teoscar Hernández      Max Kepler    Leury García  Kiké Hernández
# 1      J.D. Martinez   Wilmer Flores  Kiké Hernández    Zack Collins
# 2     Josh Donaldson   Jorge Polanco     Miguel Sanó      Max Kepler
# 3    Robbie Grossman  Kiké Hernández     Akil Baddoo    Danny Jansen
# 4      Wilmer Flores  Kiké Hernández     Curt Casali      Greg Allen
#
#                OF3
# 0     Tres Barrera
# 1   Hunter Renfroe
# 2    Danny Santana
# 3    Josh Harrison
# 4  Estevan Florial

# %% [markdown]
# # PROCESS DATA
#
# # Here we need to transform the data by melting and creating a crosstab table to show exposures for every user

# %%
points_own_df = create_points_own_df(df)

points_own_df.head()
# Out:
#                 player position  ownership  points
# 0  Lance McCullers Jr.        P      68.26   13.85
# 1          Dylan Cease        P      33.51    9.85
# 2      Adam Wainwright        P      30.32   19.55
# 3         Bryce Harper       OF      28.90   11.00
# 4        Josh Harrison       3B      28.37    7.00

# %%
# Loop through each user and create a dictionary with their data
user_data_dict = {}

for user in dk_users:
    user_data_dict[user] = melt_crosstab(agg_lineups, user)
    #user_data_dict[user]['F'] = user_data_dict[user][['F1','F2','F3','F4','F5','F6']].sum(axis=1)
    user_data_dict[user] = user_data_dict[user][['player','count','exposure']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-ca80c2d9c46e> in <module>
#       5     user_data_dict[user] = melt_crosstab(agg_lineups, user)
#       6     #user_data_dict[user]['F'] = user_data_dict[user][['F1','F2','F3','F4','F5','F6']].sum(axis=1)
# ----> 7     user_data_dict[user] = user_data_dict[user][['player','count','exposure']]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2906             if is_iterator(key):
#    2907                 key = list(key)
# -> 2908             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2909
#    2910         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# -> 1254         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1255         return keyarr, indexer
#    1256
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1302             if raise_missing:
#    1303                 not_found = list(set(key) - set(ax))
# -> 1304                 raise KeyError(f"{not_found} not in index")
#    1305
#    1306             # we skip the warning on Categorical
#
# KeyError: "['player'] not in index"

# %%
# Aggregate the various dataframes into a single one

agg_exposures = pd.DataFrame()

for user in dk_users:
    if user == dk_users[0]:
        agg_exposures = user_data_dict[user][['player','exposure']].round(2)
        agg_exposures.rename(columns={'exposure':user}, inplace=True)
    else:
        agg_exposures = pd.merge(agg_exposures, user_data_dict[user][['player','exposure']].round(2), how='outer', on='player')
        agg_exposures.rename(columns={'exposure':user}, inplace=True)
        
    agg_exposures = agg_exposures.replace(np.nan, 0.0)    
    
agg_exposures.head(25)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-e86962a63e87> in <module>
#       8         agg_exposures.rename(columns={'exposure':user}, inplace=True)
#       9     else:
# ---> 10         agg_exposures = pd.merge(agg_exposures, user_data_dict[user][['player','exposure']].round(2), how='outer', on='player')
#      11         agg_exposures.rename(columns={'exposure':user}, inplace=True)
#      12
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2906             if is_iterator(key):
#    2907                 key = list(key)
# -> 2908             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2909
#    2910         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# -> 1254         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1255         return keyarr, indexer
#    1256
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1302             if raise_missing:
#    1303                 not_found = list(set(key) - set(ax))
# -> 1304                 raise KeyError(f"{not_found} not in index")
#    1305
#    1306             # we skip the warning on Categorical
#
# KeyError: "['player'] not in index"

# %%
# Now merge the 2 datasets that we've created together into 1
master_df = pd.merge(agg_exposures, points_own_df, on='player')
non_user_cols = ['player','position','points', 'ownership']
master_df = master_df[[*non_user_cols, *master_df.columns.difference(non_user_cols)]]

print(len(master_df))
# Out:
# 56

# %% [markdown]
# # OUTPUT

# %%
master_df.sort_values('ownership', ascending=False)
# Out:
#                  player position  points  ownership  MMAdamMartin  \
# 11         Leon Edwards        F   90.97      48.22         43.33
# 17  Deiveson Figueiredo        F   19.10      42.29         34.00
# 1          Jamahal Hill        F    2.39      39.33         44.00
# 24      Israel Adesanya        F   84.68      36.53         40.67
# 3        Brandon Moreno        F   97.27      34.48         32.00
# 0        Marvin Vettori        F   62.25      33.38         48.00
# 10     Luigi Vendramini        F   27.47      26.75         20.00
# 2          Matt Frevola        F    0.00      25.62          1.33
# 6          Chase Hooper        F   51.05      24.87         20.00
# 5     Joanne Calderwood        F   55.38      24.40          2.67
# 12          Eryk Anders        F   81.17      23.86         21.33
# 23           Drew Dober        F   42.15      20.42         30.00
# 4          Brad Riddell        F   99.90      19.40         19.33
# 8         Movsar Evloev        F  138.05      19.34         42.00
# 9     Terrance McKinney        F  126.80      19.00         50.00
# 7       Steven Peterson        F   79.51      14.89         13.33
# 26       Belal Muhammad        F   57.40      14.63         22.00
# 21        Hakeem Dawodu        F   25.28      14.29          0.67
# 14         Jake Collier        F   52.00      13.94          8.67
# 27            Nate Diaz        F   44.59      13.72          6.00
# 19        Carlos Felipe        F   67.66      12.89          0.00
# 25          Demian Maia        F   21.42      12.41         22.67
# 16           Paul Craig        F  103.29      12.31          2.67
# 15        Lauren Murphy        F   84.02      11.54         32.00
# 20         Alexis Davis        F   60.98      10.62          3.33
# 22       Darren Stewart        F   33.25       9.52         15.33
# 18           Fares Ziam        F   46.40       9.45          1.33
# 13       Pannie Kianzad        F   79.75       8.39         23.33
#
#     Packersfan203  ahotebrown  gehrenberg
# 11          29.33       60.00       52.78
# 17          10.00       34.67       27.78
# 1           50.00       45.33       52.78
# 24           0.00       25.33        0.00
# 3           42.00       35.33       47.22
# 0           65.33       30.00       68.06
# 10          29.33       25.33       58.33
# 2           49.33       45.33       31.94
# 6           32.00       19.33        0.00
# 5           35.33       30.00       61.11
# 12          28.00       30.00       50.00
# 23           0.00       30.00        0.00
# 4           40.00       18.67        0.00
# 8           30.00        0.00       51.39
# 9           30.00       20.00       41.67
# 7           31.33       20.00       56.94
# 26           0.00       10.00        0.00
# 21           3.33       11.33        0.00
# 14          20.00       20.00        0.00
# 27           0.00        0.00        0.00
# 19           8.00       15.33        0.00
# 25           0.00       15.33        0.00
# 16          10.00       14.00        0.00
# 15          15.33        9.33        0.00
# 20           5.33        0.00        0.00
# 22           2.00       25.33        0.00
# 18           8.67       10.00        0.00
# 13          25.33        0.00        0.00

# %%
master_df.sort_values('ownership', ascending=False).to_csv('sample_master_df.csv',index=False)
